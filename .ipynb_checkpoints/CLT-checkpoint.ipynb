# %% [markdown]
# # Demonstration of the central limit theorem

# %%
# imports
from numpy.random import seed
from numpy.random import randint
from numpy import mean

import matplotlib.pyplot as plt
import seaborn as sns

import statistics

# %%
# seed the random number generator
seed(1)

# %% [markdown]
# ## 30 rolls

# %%
rolls = randint(1, 7, 30)
rolls
# Out:
# array([6, 4, 5, 1, 2, 4, 6, 1, 1, 2, 5, 6, 5, 2, 3, 5, 6, 3, 5, 4, 5, 3,
#        5, 6, 3, 5, 2, 2, 1, 6])

# %%
sns.distplot(rolls)

# %% [markdown]
# ## 300 rolls

# %%
rolls = randint(1, 7, 300)
rolls
# Out:
# array([2, 2, 6, 2, 2, 1, 5, 2, 1, 1, 6, 4, 3, 2, 1, 4, 6, 2, 2, 4, 5, 1,
#        2, 4, 5, 3, 5, 1, 6, 4, 2, 3, 1, 5, 2, 3, 3, 2, 1, 2, 4, 6, 5, 4,
#        6, 2, 4, 1, 1, 3, 3, 2, 4, 5, 3, 1, 1, 2, 2, 6, 4, 1, 1, 6, 6, 5,
#        6, 3, 5, 4, 6, 4, 6, 1, 4, 5, 4, 5, 5, 6, 5, 2, 1, 5, 3, 1, 6, 3,
#        5, 2, 2, 1, 3, 5, 5, 1, 5, 2, 5, 2, 1, 3, 4, 2, 3, 5, 5, 3, 3, 1,
#        2, 3, 3, 1, 6, 2, 3, 5, 1, 6, 6, 2, 3, 2, 6, 5, 3, 1, 6, 1, 2, 6,
#        1, 2, 4, 2, 2, 6, 5, 5, 4, 6, 1, 4, 1, 4, 2, 3, 6, 6, 5, 6, 1, 6,
#        1, 6, 4, 2, 2, 6, 1, 6, 1, 5, 3, 6, 4, 5, 3, 1, 6, 4, 4, 6, 6, 2,
#        3, 5, 4, 1, 1, 6, 5, 3, 5, 3, 1, 6, 4, 1, 1, 5, 6, 3, 2, 1, 5, 4,
#        1, 2, 3, 5, 5, 4, 4, 4, 4, 3, 4, 4, 6, 5, 4, 3, 5, 5, 1, 4, 4, 1,
#        4, 6, 6, 2, 1, 3, 3, 3, 1, 3, 2, 5, 1, 5, 5, 2, 4, 2, 5, 2, 3, 6,
#        2, 1, 1, 3, 5, 2, 1, 1, 4, 2, 1, 5, 4, 3, 4, 5, 6, 5, 4, 1, 1, 1,
#        5, 6, 2, 6, 5, 2, 3, 6, 3, 6, 5, 6, 4, 5, 5, 1, 4, 3, 5, 6, 4, 5,
#        3, 4, 1, 6, 6, 3, 2, 4, 3, 1, 6, 2, 5, 2])

# %%
sns.distplot(rolls)

# %% [markdown]
# ## Calculate the mean of 30 dice rolls 10 000 times

# %%
means = [mean(randint(1, 7, 30)) for _ in range(10000)]

# %%
# plot the distribution of sample means
sns.distplot(means)

# %%
plt.hist(means, bins=10)
plt.show()

# %% [markdown]
# ## Standard deviation:

# %%
statistics.stdev(means)
# Out:
# 0.3117232942087042

# %% [markdown]
# ## Calculate the mean of 3000 dice rolls 10 000 times

# %%
means = [mean(randint(1, 7, 3000)) for _ in range(10000)]

# %%
# plot the distribution of sample means
sns.distplot(means)

# %%
plt.hist(means, bins=10)
plt.show()

# %% [markdown]
# ## Standard deviation:

# %%
statistics.stdev(means)
# Out:
# 0.03100550196880315
