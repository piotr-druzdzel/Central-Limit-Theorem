# %% [markdown]
# # Demonstration of the central limit theorem

# %%
# imports
from numpy.random import seed
from numpy.random import randint
from numpy import mean

import matplotlib.pyplot as plt
import seaborn as sns

import statistics

# %%
# seed the random number generator
seed(1)

# %% [markdown]
# ## 30 rolls

# %%
rolls = randint(1, 7, 30)
rolls
# Out:
# array([6, 4, 5, 1, 2, 4, 6, 1, 1, 2, 5, 6, 5, 2, 3, 5, 6, 3, 5, 4, 5, 3,
#        5, 6, 3, 5, 2, 2, 1, 6])

# %%
sns.distplot(rolls)

# %% [markdown]
# ## 3000 rolls

# %%
rolls = randint(1, 7, 3000)
rolls
# Out:
# array([2, 2, 6, ..., 6, 1, 2])

# %%
sns.distplot(rolls)

# %% [markdown]
# ## Calculate the mean of 30 dice rolls 10000 times

# %%
means = [mean(randint(1, 7, 30)) for _ in range(10000)]

# %%
# plot the distribution of sample means
sns.distplot(means)

# %%
plt.hist(means, bins=10)
plt.show()

# %% [markdown]
# ## Standard deviation:

# %%
statistics.stdev(means)
# Out:
# 0.3114571330217476

# %% [markdown]
# ## Calculate the mean of 3000 dice rolls 10000 times

# %%
means = [mean(randint(1, 7, 3000)) for _ in range(10000)]

# %%
# plot the distribution of sample means
sns.distplot(means)

# %%
plt.hist(means, bins=10)
plt.show()

# %% [markdown]
# ## Standard deviation:

# %%
statistics.stdev(means)
# Out:
# 0.030902183744238577
